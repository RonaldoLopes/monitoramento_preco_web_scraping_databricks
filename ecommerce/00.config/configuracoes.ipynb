# %% [markdown]
# # Catálogo do projeto e configuração do banco de dados
#
# Este notebook documenta o catálogo de artefatos do projeto e as configurações necessárias para o armazenamento e processamento dos dados de monitoramento de preços.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS monitoramento_dados
COMMENT 'Catálogo criado para armazenar bases de dados do projeto';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS monitoramento
COMMENT 'Base de dados interna do catálogo';

# %%
# %SQL
CREATE TABLE monitoramento.dados_bronze
